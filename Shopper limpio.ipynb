# %%
#importar pandas, matplotlib y numpy

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Crear un dataframe con el archivo Shopper_DataQuality_Report.csv y muestrar las primeras 5 filas
df = pd.read_csv('C:\\Users\\danym\\Documents\\GitHub\\Proyecto-de-MIT\\Bases de datos\\Shopper_DataQuality_Report.csv')
df.head()
# Out:
#              StartDate              EndDate      Status  Progress  \
# 0  2025-09-24 18:05:30  2025-09-24 18:33:02  IP Address        59
# 1  2025-09-24 18:33:34  2025-09-24 18:33:46  IP Address        10
# 2  2025-10-01 16:27:28  2025-10-01 16:46:10  IP Address         0
# 3  2025-10-02 00:35:36  2025-10-02 00:36:29  IP Address         9
# 4  2025-10-02 23:06:01  2025-10-02 23:06:11  IP Address        18
#
#    DurationSec  Finished         RecordedDate         ResponseId Campus Group  \
# 0         1651     False  2025-10-01 18:33:05  R_5ujPYTPqbi5aU93    NaN   NaN
# 1           11     False  2025-10-01 18:33:48  R_3PbMNXYbhK76K2T    NaN   NaN
# 2         1121     False  2025-10-08 16:46:11  R_7JFNsL6uIHNhiAV    CCM    12
# 3           53     False  2025-10-09 00:36:32  R_7n3m3AuBZuk7BB0    CSF    23
# 4            9     False  2025-10-09 23:06:15  R_7LZKOcuTDfF8pPs    GDL    18
#
#    ...        Long       PurchaseSelection CampusGroup_ID ProgressIssue  \
# ...

# %%
#Eliminar todas las filas que en la columna de "Finished" tengan el valor de "False"
df = df[df['Finished'] == True]
df.head()
# Out:
#                StartDate              EndDate      Status  Progress  \
# 146  2025-10-07 22:33:25  2025-10-08 18:09:50  IP Address       100
# 147  2025-11-13 18:43:11  2025-11-14 19:25:06  IP Address       100
# 148  2025-11-13 18:42:55  2025-11-19 15:05:18  IP Address       100
# 149  2025-11-19 16:24:11  2025-11-20 17:56:40  IP Address       100
# 150  2025-11-18 23:05:19  2025-11-21 00:01:36  IP Address       100
#
#      DurationSec  Finished         RecordedDate         ResponseId Campus  \
# 146        70585      True  2025-10-08 18:09:51  R_7GJEGBpXa27ARSL    GDL
# 147        88915      True  2025-11-14 19:25:07  R_5m4tfmGaUR5wJHb    SIN
# 148       505342      True  2025-11-19 15:05:19  R_7yj4TpxtOzDMvuK    SLP
# 149        91949      True  2025-11-20 17:56:41  R_6HU6S9PNqq5OXO9    SLP
# 150       176177      True  2025-11-21 00:01:37  R_1hlzKvE2XxGSIKJ    CVA
#
#                        Group  ... Long  \
# 146                       20  ...  0.0
# ...

# %%
#Elimina las columnas que no son necesarias para el análisis
df = df.drop(columns=['StartDate', 'EndDate', 'Status', 'Progress', 'DurationSec', 'RecordedDate', 'ResponseId', 'Lat', 'Long','ProgressIssue','DurationSecIssue','Source_Report','LatitudeF','LongitudeF','RadiusSurvey','DurationSecSigma'])
df.head()
# Out:
#      Finished Campus                    Group PurchaseOther  \
# 146      True    GDL                       20        Lonche
# 147      True    SIN  Higuera,Pe√±a,Sepulbeda           NaN
# 148      True    SLP   Gonzalez,Santoyo,Gomez           NaN
# 149      True    SLP   Gonzalez,Santoyo,Gomez           NaN
# 150      True    CVA            Boyas,Barrera           NaN
#
#              TotalSpend BuyingFrequency ImpulsePurchase  \
# 146      50 – 100 pesos       Bi-Weekly             Yes
# 147          200+ pesos         Monthly             Yes
# 148  Less than 50 pesos          Weekly              No
# 149      50 – 100 pesos          Weekly             Yes
# 150  Less than 50 pesos          Weekly              No
#
#                      ImpulsePurchaseItem  \
# 146                            Empanada
# 147                               73iukj
# 148                                  NaN
# 149  Cigarretes, Coke, and a protein bar
# 150                                  NaN
#
# ...
